# %% [markdown]
# # Capstone project - provide use the comparison of 2 cities based on the data available #

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize  # tranform JSON file into a pandas dataframe
import pandas as pd
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %% [markdown]
# ## Read the Wikipedia page for City1 ##

# %%
city1_address = 'Saskatoon, Saskatchewan, Canada'
table=pd.read_html("https://en.wikipedia.org/wiki/Saskatoon",attrs={"class":"infobox geography vcard"})[0]
loc=table[table[table.columns[0]].str.match('^Population.*')==True].index[0]
print("Population: ",int(table.loc[[loc+1]][table.columns[1]].to_list()[0]))
print("Density: ",(table.loc[[loc+2]][table.columns[1]].to_list()[0]))
# Out:
# Population:  246376
# Density:  1,080.0/km2 (2,797/sq mi)

# %% [markdown]
# ## Read the Wikipedia page for City2 ##

# %%
city2_address = 'Fremont, California, USA'
table=pd.read_html("https://en.wikipedia.org/wiki/Fremont,_California",attrs={"class":"infobox geography vcard"})[0]
loc=table[table[table.columns[0]].str.match('^Population.*')==True].index[0]
print("Population: ",int(table.loc[[loc+1]][table.columns[1]].to_list()[0]))
print("Density: ",(table.loc[[loc+4]][table.columns[1]].to_list()[0]))
# Out:
# Population:  214089
# Density:  2,400/sq mi (940/km2)

# %% [markdown]
# ## Get the Neighborhoods for City1 ##

# %%
source = requests.get("https://canadianvisa.org/blog/cities-and-places/saskatoon/neighborhoods").text
soup = BeautifulSoup(source, 'lxml')
table = soup.find_all("h2")
for i in table:
    str(i).replace("<h2>","")
table[1:5]
# Out:
# [<h2>Evergreen</h2>,
#  <h2>Adelaide or Churchill</h2>,
#  <h2>Mayfair</h2>,
#  <h2>Lakeview</h2>]

# %% [markdown]
# ### Creating function to get venues from FourSquare API

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=10000):
    
    venues_list=[]
    CLIENT_ID="ASX3DZRL0RJC2H3VLR1YDHFGSBVU2ITFCZ3UUYKRZSIWV0FR"
    CLIENT_SECRET="SAFPB5VK2BFQHTN3VWKHFHTE0YGCENI5SJWIOCUQWIYKM3DT"
    VERSION='20180323'
    LIMIT=100
    url = 'https://api.foursquare.com/v2/venues/explore'

    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)

        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)

        #print (url)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        #print(results)
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Define cities for comparison

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ## Define the neighborhoods for both cities (it was hard to get this publicly in a nice format)

# %%
city1_dist=['Evergreen','Adelaide','Mayfair','Lakeview']
city2_dist=['Centerville', 'Niles', 'Irvington', 'Warm Springs']
city_df = []
for dist in city1_dist:
    city_df.append(dist+","+city1_address)

for dist in city2_dist:
    city_df.append(dist+","+city2_address)

city_df
# Out:
# ['Evergreen,Saskatoon, Saskatchewan, Canada',
#  'Adelaide,Saskatoon, Saskatchewan, Canada',
#  'Mayfair,Saskatoon, Saskatchewan, Canada',
#  'Lakeview,Saskatoon, Saskatchewan, Canada',
#  'Centerville,Fremont, California, USA',
#  'Niles,Fremont, California, USA',
#  'Irvington,Fremont, California, USA',
#  'Warm Springs,Fremont, California, USA']

# %% [markdown]
# ## Get the Coordinates for all the neighborhoods using GeoLocator API

# %%
#city1_df=pd.DataFrame(columns=['Neighborhood','Latitude','Longitude'])
city_df=[]
for dist in city1_dist:
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(dist+","+city1_address)
    latitude = location.latitude
    longitude = location.longitude
    city_df.append([dist+","+city1_address,latitude,longitude])

city_df=pd.DataFrame(city_df,columns=['Neighborhood','Latitude','Longitude'])

city_df2=[]
for dist in city2_dist:
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(dist+","+city2_address)
    latitude = location.latitude
    longitude = location.longitude
    print(dist,latitude,longitude)
    city_df2.append([dist+","+city2_address,latitude,longitude])

city_df=city_df.append(pd.DataFrame(city_df2,columns=['Neighborhood','Latitude','Longitude']))

## Adding San Jose coordinates manually, as GeoLocator was giving error for this
city_df=city_df.append(pd.DataFrame([['Mission San Jose,Fremont, California, USA',37.534721, -121.920418]],columns=['Neighborhood','Latitude','Longitude']))

city_df
# Out:
# Centerville 37.559645599999996 -122.0067569
# Niles 37.5781679 -121.9809177
# Irvington 37.5322543 -121.9538481
# Warm Springs 37.5019913 -121.9392084
#                                 Neighborhood   Latitude   Longitude
# 0  Evergreen,Saskatoon, Saskatchewan, Canada  52.169376 -106.569080
# 1   Adelaide,Saskatoon, Saskatchewan, Canada  52.098655 -106.640908
# 2    Mayfair,Saskatoon, Saskatchewan, Canada  52.141689 -106.678728
# 3   Lakeview,Saskatoon, Saskatchewan, Canada  52.097643 -106.595409
# 0       Centerville,Fremont, California, USA  37.559646 -122.006757
# 1             Niles,Fremont, California, USA  37.578168 -121.980918
# 2         Irvington,Fremont, California, USA  37.532254 -121.953848
# 3      Warm Springs,Fremont, California, USA  37.501991 -121.939208
# 0  Mission San Jose,Fremont, California, USA  37.534721 -121.920418

# %%
city_list=city_df

#for city in city_list:
city_venues = getNearbyVenues(names = city_list['Neighborhood'], latitudes = city_list['Latitude'],longitudes = city_list['Longitude'])
print('There are {} uniques categories.'.format(len(city_venues['Venue Category'].unique())))
# one hot encoding
city_onehot = pd.get_dummies(city_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
city_onehot['Neighborhood'] = city_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [city_onehot.columns[-1]] + list(city_onehot.columns[:-1])
city_onehot = city_onehot[fixed_columns]

#city_onehot.head()
city_grouped = city_onehot.groupby('Neighborhood').mean().reset_index()
print(city_grouped)
num_top_venues = 10

for hood in city_grouped['Neighborhood']:
    #print("----"+hood+"----")
    temp = city_grouped[city_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = city_grouped['Neighborhood']

for ind in np.arange(city_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(city_grouped.iloc[ind, :], num_top_venues)

print(neighborhoods_venues_sorted)

# set number of clusters
kclusters = 5
city_grouped_clustering = city_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(city_grouped_clustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# Evergreen,Saskatoon, Saskatchewan, Canada
# Adelaide,Saskatoon, Saskatchewan, Canada
# Mayfair,Saskatoon, Saskatchewan, Canada
# Lakeview,Saskatoon, Saskatchewan, Canada
# Centerville,Fremont, California, USA
# Niles,Fremont, California, USA
# Irvington,Fremont, California, USA
# Warm Springs,Fremont, California, USA
# Mission San Jose,Fremont, California, USA
# There are 130 uniques categories.
#                                 Neighborhood  Afghan Restaurant  \
# 0   Adelaide,Saskatoon, Saskatchewan, Canada               0.00
# 1       Centerville,Fremont, California, USA               0.01
# 2  Evergreen,Saskatoon, Saskatchewan, Canada               0.00
# 3         Irvington,Fremont, California, USA               0.00
# 4   Lakeview,Saskatoon, Saskatchewan, Canada               0.00
# 5    Mayfair,Saskatoon, Saskatchewan, Canada               0.00
# 6  Mission San Jose,Fremont, California, USA               0.00
# 7             Niles,Fremont, California, USA               0.01
# 8      Warm Springs,Fremont, California, USA               0.00
#
#    American Restaurant  Asian Restaurant  BBQ Joint  Bagel Shop    Bakery  \
# 0             0.027397          0.013699       0.00        0.00  0.027397
# 1             0.010000          0.000000       0.00        0.01  0.040000
# 2             0.030000          0.040000       0.00        0.00  0.040000
# 3             0.010000          0.000000       0.01        0.01  0.030000
# 4             0.035714          0.017857       0.00        0.00  0.035714
# 5             0.030000          0.030000       0.00        0.00  0.040000
# 6             0.010000          0.000000       0.01        0.00  0.040000
# 7             0.010000          0.000000       0.00        0.01  0.040000
# 8             0.010000          0.020000       0.01        0.00  0.030000
#
#        Bank       Bar  Beach  ...  Tennis Court  Thai Restaurant  Theater  \
# 0  0.013699  0.013699   0.00  ...          0.00         0.013699     0.00
# 1  0.000000  0.000000   0.00  ...          0.00         0.040000     0.00
# 2  0.000000  0.010000   0.00  ...          0.00         0.010000     0.01
# 3  0.000000  0.000000   0.00  ...          0.01         0.020000     0.00
# 4  0.000000  0.017857   0.00  ...          0.00         0.017857     0.00
# 5  0.000000  0.010000   0.00  ...          0.00         0.010000     0.01
# 6  0.000000  0.000000   0.00  ...          0.01         0.020000     0.00
# 7  0.000000  0.000000   0.01  ...          0.01         0.030000     0.00
# 8  0.000000  0.000000   0.00  ...          0.00         0.030000     0.00
#
#    Trail  Train Station  Vietnamese Restaurant  Warehouse Store  Wine Shop  \
# 0   0.00       0.013699                   0.00         0.013699       0.00
# 1   0.02       0.000000                   0.00         0.000000       0.00
# 2   0.01       0.000000                   0.01         0.010000       0.00
# 3   0.03       0.000000                   0.00         0.000000       0.01
# 4   0.00       0.017857                   0.00         0.017857       0.00
# 5   0.01       0.000000                   0.02         0.000000       0.00
# 6   0.05       0.000000                   0.00         0.000000       0.01
# 7   0.02       0.000000                   0.01         0.000000       0.00
# 8   0.03       0.000000                   0.00         0.010000       0.01
#
#    Yoga Studio       Zoo
# 0         0.00  0.013699
# 1         0.00  0.000000
# 2         0.00  0.010000
# 3         0.01  0.000000
# 4         0.00  0.017857
# 5         0.00  0.010000
# 6         0.00  0.000000
# 7         0.00  0.000000
# 8         0.01  0.000000
#
# [9 rows x 131 columns]
#                  venue  freq
# 0          Coffee Shop  0.05
# 1                  Pub  0.05
# 2        Grocery Store  0.04
# 3          Pizza Place  0.04
# 4                 Café  0.04
# 5       Sandwich Place  0.03
# 6           Restaurant  0.03
# 7                Hotel  0.03
# 8  American Restaurant  0.03
# 9   Mexican Restaurant  0.03
#
#
#                 venue  freq
# 0         Coffee Shop  0.07
# 1       Grocery Store  0.06
# 2      Ice Cream Shop  0.04
# 3     Thai Restaurant  0.04
# 4              Bakery  0.04
# 5    Sushi Restaurant  0.04
# 6                Park  0.04
# 7      Breakfast Spot  0.03
# 8  Falafel Restaurant  0.02
# 9  Chinese Restaurant  0.02
#
#
#                  venue  freq
# 0          Coffee Shop  0.07
# 1           Restaurant  0.05
# 2                Hotel  0.05
# 3          Pizza Place  0.04
# 4     Asian Restaurant  0.04
# 5                  Pub  0.04
# 6               Bakery  0.04
# 7                 Café  0.04
# 8           Steakhouse  0.03
# 9  American Restaurant  0.03
#
#
#                   venue  freq
# 0           Coffee Shop  0.06
# 1         Grocery Store  0.05
# 2        Ice Cream Shop  0.05
# 3  Fast Food Restaurant  0.04
# 4    Falafel Restaurant  0.03
# 5           Pizza Place  0.03
# 6                Bakery  0.03
# 7                  Park  0.03
# 8                   Gym  0.03
# 9                 Trail  0.03
#
#
#                  venue  freq
# 0                  Pub  0.07
# 1          Coffee Shop  0.05
# 2                 Café  0.05
# 3   Mexican Restaurant  0.04
# 4                Hotel  0.04
# 5       Breakfast Spot  0.04
# 6  American Restaurant  0.04
# 7            Bookstore  0.04
# 8          Pizza Place  0.04
# 9           Restaurant  0.04
#
#
#                  venue  freq
# 0           Restaurant  0.05
# 1                Hotel  0.05
# 2                 Café  0.04
# 3               Bakery  0.04
# 4          Coffee Shop  0.04
# 5                  Pub  0.04
# 6          Pizza Place  0.03
# 7     Asian Restaurant  0.03
# 8           Steakhouse  0.03
# 9  American Restaurant  0.03
#
#
#                   venue  freq
# 0           Coffee Shop  0.07
# 1                 Trail  0.05
# 2        Ice Cream Shop  0.05
# 3  Fast Food Restaurant  0.04
# 4                Bakery  0.04
# 5         Grocery Store  0.04
# 6    Mexican Restaurant  0.03
# 7                  Park  0.03
# 8    Falafel Restaurant  0.03
# 9           Pizza Place  0.03
#
#
#                   venue  freq
# 0                  Park  0.07
# 1           Coffee Shop  0.07
# 2         Grocery Store  0.05
# 3                Bakery  0.04
# 4      Sushi Restaurant  0.04
# 5        Breakfast Spot  0.04
# 6       Thai Restaurant  0.03
# 7    Mexican Restaurant  0.03
# 8  Fast Food Restaurant  0.03
# 9        Ice Cream Shop  0.03
#
#
#                   venue  freq
# 0           Coffee Shop  0.07
# 1  Fast Food Restaurant  0.04
# 2                   Gym  0.04
# 3         Grocery Store  0.04
# 4             Juice Bar  0.03
# 5    Mexican Restaurant  0.03
# 6                Bakery  0.03
# 7      Sushi Restaurant  0.03
# 8       Thai Restaurant  0.03
# 9                 Trail  0.03
#
#
#                                 Neighborhood 1st Most Common Venue  \
# 0   Adelaide,Saskatoon, Saskatchewan, Canada                   Pub
# 1       Centerville,Fremont, California, USA           Coffee Shop
# 2  Evergreen,Saskatoon, Saskatchewan, Canada           Coffee Shop
# 3         Irvington,Fremont, California, USA           Coffee Shop
# 4   Lakeview,Saskatoon, Saskatchewan, Canada                   Pub
# 5    Mayfair,Saskatoon, Saskatchewan, Canada                 Hotel
# 6  Mission San Jose,Fremont, California, USA           Coffee Shop
# 7             Niles,Fremont, California, USA                  Park
# 8      Warm Springs,Fremont, California, USA           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop                  Café         Grocery Store
# 1         Grocery Store      Sushi Restaurant                Bakery
# 2                 Hotel            Restaurant                Bakery
# 3         Grocery Store        Ice Cream Shop  Fast Food Restaurant
# 4           Coffee Shop                  Café           Pizza Place
# 5            Restaurant           Coffee Shop                   Pub
# 6        Ice Cream Shop                 Trail                Bakery
# 7           Coffee Shop         Grocery Store        Breakfast Spot
# 8  Fast Food Restaurant                   Gym         Grocery Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Pizza Place            Restaurant    Mexican Restaurant
# 1        Ice Cream Shop                  Park       Thai Restaurant
# 2                   Pub      Asian Restaurant                  Café
# 3                   Gym           Pizza Place                 Trail
# 4    Mexican Restaurant            Restaurant   American Restaurant
# 5                  Café                Bakery            Steakhouse
# 6  Fast Food Restaurant         Grocery Store                   Gym
# 7      Sushi Restaurant                Bakery  Fast Food Restaurant
# 8      Sushi Restaurant             Juice Bar                 Trail
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Sandwich Place        Breakfast Spot              Bookstore
# 1        Breakfast Spot                 Trail     Mexican Restaurant
# 2           Pizza Place   American Restaurant          Grocery Store
# 3                Bakery    Falafel Restaurant                   Park
# 4                Bakery                 Hotel         Breakfast Spot
# 5           Pizza Place      Asian Restaurant    American Restaurant
# 6    Mexican Restaurant           Pizza Place     Falafel Restaurant
# 7    Chinese Restaurant    Mexican Restaurant        Thai Restaurant
# 8       Thai Restaurant                Bakery     Mexican Restaurant
# array([3, 2, 0, 4, 3], dtype=int32)

# %% [markdown]
# ## Process the data for Cosine Similarity (remove Neighborhood, group on cities)

# %%
def get_city(neighborhood):
    return neighborhood.split(",")[1]+","+neighborhood.split(",")[2]+","+neighborhood.split(",")[3] 

city_group2 = city_onehot.groupby('Neighborhood').sum().reset_index()
#city_group2
city_group2['City']=city_group2.apply(lambda x: get_city(x['Neighborhood']),axis=1)
city_group2_new = city_group2.drop(['Neighborhood'],axis=1).groupby('City').sum()
#city_group2_new = city_group2.drop(['Neighborhood'],axis=1).sort_values('City', ascending=False)
#city_group2_new.set_index('City',inplace=True)

# %% [markdown]
# ## Calculate Similarity between the cities

# %%
## METHOD 1

from sklearn.metrics import pairwise_distances
import sklearn.metrics.pairwise as pairwise

pairwise.cosine_similarity(city_group2_new)[0][1]
# Out:
# 0.5692370799616825

# %%
## METHOD 2

import scipy.spatial as spatial
spatial.distance.cosine(city_group2_new.transpose().iloc[:,0],city_group2_new.transpose().iloc[:,1])
# Out:
# 0.343105388838693

# %% [markdown]
# ## Find top 10 venues for these cities

# %%
city_vens=city_group2_new.transpose()
city1_ven=city_vens[[city_vens.columns[0]]].sort_values(city_vens.columns[0],ascending=False)
city1_ven.head(10)
# Out:
# City                  Fremont, California, USA
# Coffee Shop                                 34
# Grocery Store                               24
# Park                                        19
# Ice Cream Shop                              19
# Bakery                                      18
# Fast Food Restaurant                        17
# Trail                                       15
# Sushi Restaurant                            15
# Thai Restaurant                             14
# Mexican Restaurant                          13

# %%
city2_ven=city_vens[[city_vens.columns[1]]].sort_values(city_vens.columns[1],ascending=False)
city2_ven.head(10)
# Out:
# City                 Saskatoon, Saskatchewan, Canada
# Coffee Shop                                       18
# Pub                                               16
# Hotel                                             14
# Café                                              14
# Restaurant                                        14
# Bakery                                            12
# Pizza Place                                       12
# American Restaurant                               10
# Grocery Store                                      9
# Asian Restaurant                                   9

# %%
from IPython.display import display
pd.options.display.max_rows = None
display(city_vens)
#print(city_vens)
# Out:
# City                           Fremont, California, USA  \
# Afghan Restaurant                                     2
# American Restaurant                                   5
# Asian Restaurant                                      2
# BBQ Joint                                             3
# Bagel Shop                                            3
# Bakery                                               18
# Bank                                                  0
# Bar                                                   0
# Beach                                                 1
# Beer Garden                                           2
# Big Box Store                                         1
# Bookstore                                             5
# Bowling Alley                                         4
# Brazilian Restaurant                                  0
# Breakfast Spot                                       11
# Brewery                                               2
# Bubble Tea Shop                                       4
# Burger Joint                                          2
# Burmese Restaurant                                    5
# Café                                                  6
# Cajun / Creole Restaurant                             0
# Camera Store                                          0
# Caribbean Restaurant                                  0
# Cheese Shop                                           0
# Chinese Restaurant                                    8
# Church                                                3
# Clothing Store                                        0
# Coffee Shop                                          34
# Comedy Club                                           3
# Convenience Store                                     4
# Cosmetics Shop                                        3
# Creperie                                              0
# Cupcake Shop                                          0
# Deli / Bodega                                         1
# Dessert Shop                                          6
# Dim Sum Restaurant                                    0
# Diner                                                 0
# Discount Store                                        2
# Dive Bar                                              0
# Dog Run                                               5
# Donut Shop                                            6
# Dumpling Restaurant                                   2
# Falafel Restaurant                                   12
# Farm                                                  2
# Farmers Market                                        3
# Fast Food Restaurant                                 17
# Food Court                                            0
# Food Truck                                            2
# French Restaurant                                     3
# Fried Chicken Joint                                   3
# Frozen Yogurt Shop                                    7
# Furniture / Home Store                                1
# Gas Station                                           0
# Gastropub                                             0
# German Restaurant                                     4
# Gift Shop                                             0
# Gluten-free Restaurant                                0
# Golf Course                                           0
# Greek Restaurant                                      3
# Grocery Store                                        24
# Gym                                                  12
# Gym / Fitness Center                                  7
# Gymnastics Gym                                        2
# Hardware Store                                        0
# Hawaiian Restaurant                                   2
# Hockey Arena                                          0
# Hot Dog Joint                                         3
# Hotel                                                 1
# Hunan Restaurant                                      2
# Ice Cream Shop                                       19
# Indian Restaurant                                     4
# Indie Movie Theater                                   0
# Italian Restaurant                                    0
# Japanese Restaurant                                   6
# Juice Bar                                             6
# Karaoke Bar                                           0
# Lake                                                  7
# Latin American Restaurant                             0
# Library                                               5
# Liquor Store                                          0
# Lounge                                                0
# Mediterranean Restaurant                              3
# Mexican Restaurant                                   13
# Middle Eastern Restaurant                             1
# Mountain                                              3
# Movie Theater                                         8
# Museum                                                0
# Nature Preserve                                       2
# New American Restaurant                               0
# Outdoor Supply Store                                  1
# Paper / Office Supplies Store                         0
# Park                                                 19
# Pet Store                                            10
# Pharmacy                                              0
# Pizza Place                                          10
# Playground                                            3
# Pool                                                  0
# Pool Hall                                             5
# Pub                                                   1
# Racetrack                                             1
# Restaurant                                            4
# Salon / Barbershop                                    1
# Sandwich Place                                        8
# Scenic Lookout                                        3
# Seafood Restaurant                                    3
# Shanghai Restaurant                                   6
# Shipping Store                                        4
# Shoe Store                                            0
# Shopping Mall                                         3
# Smoke Shop                                            5
# Smoothie Shop                                         0
# Soccer Stadium                                        0
# Spa                                                   7
# Sporting Goods Shop                                   4
# Steakhouse                                            0
# Supermarket                                           0
# Sushi Restaurant                                     15
# Taco Place                                            3
# Taiwanese Restaurant                                  2
# Tea Room                                              3
# Tennis Court                                          3
# Thai Restaurant                                      14
# Theater                                               0
# Trail                                                15
# Train Station                                         0
# Vietnamese Restaurant                                 1
# Warehouse Store                                       1
# Wine Shop                                             3
# Yoga Studio                                           2
# Zoo                                                   0
#
# City                           Saskatoon, Saskatchewan, Canada
# Afghan Restaurant                                            0
# American Restaurant                                         10
# Asian Restaurant                                             9
# BBQ Joint                                                    0
# Bagel Shop                                                   0
# Bakery                                                      12
# Bank                                                         1
# Bar                                                          4
# Beach                                                        0
# Beer Garden                                                  0
# Big Box Store                                                0
# Bookstore                                                    8
# Bowling Alley                                                0
# Brazilian Restaurant                                         4
# Breakfast Spot                                               8
# Brewery                                                      0
# Bubble Tea Shop                                              0
# Burger Joint                                                 3
# Burmese Restaurant                                           0
# Café                                                        14
# Cajun / Creole Restaurant                                    4
# Camera Store                                                 2
# Caribbean Restaurant                                         4
# Cheese Shop                                                  4
# Chinese Restaurant                                           4
# Church                                                       0
# Clothing Store                                               2
# Coffee Shop                                                 18
# Comedy Club                                                  4
# Convenience Store                                            0
# Cosmetics Shop                                               1
# Creperie                                                     2
# Cupcake Shop                                                 2
# Deli / Bodega                                                0
# Dessert Shop                                                 0
# Dim Sum Restaurant                                           2
# Diner                                                        2
# Discount Store                                               0
# Dive Bar                                                     1
# Dog Run                                                      0
# Donut Shop                                                   0
# Dumpling Restaurant                                          0
# Falafel Restaurant                                           0
# Farm                                                         0
# Farmers Market                                               4
# Fast Food Restaurant                                         2
# Food Court                                                   2
# Food Truck                                                   0
# French Restaurant                                            2
# Fried Chicken Joint                                          1
# Frozen Yogurt Shop                                           1
# Furniture / Home Store                                       0
# Gas Station                                                  2
# Gastropub                                                    3
# German Restaurant                                            0
# Gift Shop                                                    4
# Gluten-free Restaurant                                       5
# Golf Course                                                  3
# Greek Restaurant                                             2
# Grocery Store                                                9
# Gym                                                          5
# Gym / Fitness Center                                         1
# Gymnastics Gym                                               0
# Hardware Store                                               1
# Hawaiian Restaurant                                          0
# Hockey Arena                                                 2
# Hot Dog Joint                                                0
# Hotel                                                       14
# Hunan Restaurant                                             0
# Ice Cream Shop                                               6
# Indian Restaurant                                            4
# Indie Movie Theater                                          4
# Italian Restaurant                                           4
# Japanese Restaurant                                          0
# Juice Bar                                                    0
# Karaoke Bar                                                  2
# Lake                                                         0
# Latin American Restaurant                                    2
# Library                                                      0
# Liquor Store                                                 2
# Lounge                                                       2
# Mediterranean Restaurant                                     0
# Mexican Restaurant                                           8
# Middle Eastern Restaurant                                    0
# Mountain                                                     0
# Movie Theater                                                4
# Museum                                                       3
# Nature Preserve                                              0
# New American Restaurant                                      4
# Outdoor Supply Store                                         0
# Paper / Office Supplies Store                                1
# Park                                                         0
# Pet Store                                                    0
# Pharmacy                                                     1
# Pizza Place                                                 12
# Playground                                                   0
# Pool                                                         2
# Pool Hall                                                    0
# Pub                                                         16
# Racetrack                                                    0
# Restaurant                                                  14
# Salon / Barbershop                                           0
# Sandwich Place                                               5
# Scenic Lookout                                               4
# Seafood Restaurant                                           0
# Shanghai Restaurant                                          0
# Shipping Store                                               0
# Shoe Store                                                   1
# Shopping Mall                                                4
# Smoke Shop                                                   0
# Smoothie Shop                                                1
# Soccer Stadium                                               1
# Spa                                                          0
# Sporting Goods Shop                                          4
# Steakhouse                                                   8
# Supermarket                                                  2
# Sushi Restaurant                                             0
# Taco Place                                                   0
# Taiwanese Restaurant                                         0
# Tea Room                                                     0
# Tennis Court                                                 0
# Thai Restaurant                                              4
# Theater                                                      2
# Trail                                                        2
# Train Station                                                2
# Vietnamese Restaurant                                        3
# Warehouse Store                                              3
# Wine Shop                                                    0
# Yoga Studio                                                  0
# Zoo                                                          4

# %%
city_merged = city_list.copy(deep=True)
city_merged.reset_index()

# add clustering labels
city_merged['Cluster Labels'] = kmeans.labels_

# merge city_grouped with city_data to add latitude/longitude for each neighborhood
city_merged = city_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

city_merged.to_csv("CityComparison_data.csv")

city_merged # check the last columns!
# Out:
#                                 Neighborhood   Latitude   Longitude  \
# 0  Evergreen,Saskatoon, Saskatchewan, Canada  52.169376 -106.569080
# 1   Adelaide,Saskatoon, Saskatchewan, Canada  52.098655 -106.640908
# 2    Mayfair,Saskatoon, Saskatchewan, Canada  52.141689 -106.678728
# 3   Lakeview,Saskatoon, Saskatchewan, Canada  52.097643 -106.595409
# 0       Centerville,Fremont, California, USA  37.559646 -122.006757
# 1             Niles,Fremont, California, USA  37.578168 -121.980918
# 2         Irvington,Fremont, California, USA  37.532254 -121.953848
# 3      Warm Springs,Fremont, California, USA  37.501991 -121.939208
# 0  Mission San Jose,Fremont, California, USA  37.534721 -121.920418
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               3           Coffee Shop                 Hotel
# 1               2                   Pub           Coffee Shop
# 2               0                 Hotel            Restaurant
# 3               4                   Pub           Coffee Shop
# 0               3           Coffee Shop         Grocery Store
# 1               0                  Park           Coffee Shop
# 2               4           Coffee Shop         Grocery Store
# 3               2           Coffee Shop  Fast Food Restaurant
# 0               1           Coffee Shop        Ice Cream Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0            Restaurant                Bakery                   Pub
# 1                  Café         Grocery Store           Pizza Place
# 2           Coffee Shop                   Pub                  Café
# 3                  Café           Pizza Place    Mexican Restaurant
# 0      Sushi Restaurant                Bakery        Ice Cream Shop
# 1         Grocery Store        Breakfast Spot      Sushi Restaurant
# 2        Ice Cream Shop  Fast Food Restaurant                   Gym
# 3                   Gym         Grocery Store      Sushi Restaurant
# 0                 Trail                Bakery  Fast Food Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Asian Restaurant                  Café           Pizza Place
# 1            Restaurant    Mexican Restaurant        Sandwich Place
# 2                Bakery            Steakhouse           Pizza Place
# 3            Restaurant   American Restaurant                Bakery
# 0                  Park       Thai Restaurant        Breakfast Spot
# 1                Bakery  Fast Food Restaurant    Chinese Restaurant
# 2           Pizza Place                 Trail                Bakery
# 3             Juice Bar                 Trail       Thai Restaurant
# 0         Grocery Store                   Gym    Mexican Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0   American Restaurant          Grocery Store
# 1        Breakfast Spot              Bookstore
# 2      Asian Restaurant    American Restaurant
# 3                 Hotel         Breakfast Spot
# 0                 Trail     Mexican Restaurant
# 1    Mexican Restaurant        Thai Restaurant
# 2    Falafel Restaurant                   Park
# 3                Bakery     Mexican Restaurant
# 0           Pizza Place     Falafel Restaurant

# %% [markdown]
# ## Put all clusters on the map

# %%
# Matplotlib and associated plotting modules
# !pip install folium
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(city_merged['Latitude'], city_merged['Longitude'], city_merged['Neighborhood'],kmeans.labels_):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
